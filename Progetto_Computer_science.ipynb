# %%
import pandas as pd 
import numpy as np 
import re

# %% [markdown]
# ## Upload the two datasets

# %%
google_app = pd.read_csv("/Users/lorenzofamiglini/Desktop/googleplaystore.csv")
user_reviews = pd.read_csv("/Users/lorenzofamiglini/Desktop/googleplaystore_user_reviews.csv")
google_app.head()
user_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ## Exercise 1: Convert the app sizes to a number

# %%
#Changing column's name from Size to Size in Mb
google_app.rename({"Size" : "Size (Megabyte)"}, axis = "columns", inplace = True) #The column can be renamed as a function of the Mb

# %%
google_app.dropna(subset=["Android Ver"], inplace = True) #delete Nan from Android Ver

# %%
google_app["Size (Megabyte)"].str.extractall(r"(\d*\S?\d*)[k]") #Understand the composition of the values with letter "k"
google_app["Size (Megabyte)"].replace("k", value = "", regex = True, inplace = True) #Delete letter k

# %%
n = google_app["Size (Megabyte)"].str.extractall(r"(\d+.?\d+?$)") # extract the rows in kb
x = n.index.get_level_values(0) #save the index of the corresponding rows of the values in kb:

# %%
google_app["Size (Megabyte)"].str.extractall(r"(\d*\S?\d*)(M)") #Understand the composition of the values with letter "Mb"
google_app["Size (Megabyte)"].replace("M", value = "", regex = True, inplace = True)#Delete letter M from the other rows

# %% [markdown]
# ## Exercise 3: Transform “Varies with device” into a missing value

# %% [markdown]
# NB: It's useful to solve point 1 being a string that creates problems for me in converting to Megabytes

# %%
google_app[google_app == "Varies with device"] = np.nan #I treat it as a nan value

# %%
google_app[google_app == "Varies with device"].count() #check if there's still "Varies with device" there
# Out:
# App                0
# Category           0
# Rating             0
# Reviews            0
# Size (Megabyte)    0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        0
# Android Ver        0
# dtype: int64

# %% [markdown]
# ## Resume exercise one to complete the conversion of kb into Mb

# %%
google_app["Size (Megabyte)"].str.extractall(r"([A-z])", flags = re.IGNORECASE ).count() #check if there are any letters left.
# Out:
# 0    0
# dtype: int64

# %%
google_app["Size (Megabyte)"] = pd.to_numeric(google_app["Size (Megabyte)"]) #convert all values to float to have the same scale with respect to MB
google_app["Size (Megabyte)"].loc[x] = (google_app["Size (Megabyte)"].loc[x]/1000) #conversion from kb to mb and divide divide per thousand
google_app.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size (Megabyte)     Installs  Type Price Content Rating  \
# 0     159             19.0      10,000+  Free     0       Everyone
# 1     967             14.0     500,000+  Free     0       Everyone
# 2   87510              8.7   5,000,000+  Free     0       Everyone
# 3  215644             25.0  50,000,000+  Free     0           Teen
# 4     967              2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up
# 3               Art & Design      June 8, 2018         NaN    4.2 and up
# 4    Art & Design;Creativity     June 20, 2018         1.1    4.4 and up

# %% [markdown]
# ## Exercise 2: Convert the number of installs to a number

# %%
google_app["Installs"].replace("\+|,", value = "", regex = True, inplace = True) #first of all I remove the "+" sign and commas

# %%
google_app["Installs"] = pd.to_numeric(google_app["Installs"]) #convert into int64
google_app["Installs"].head(20) #verify the output
# Out:
# 0        10000
# 1       500000
# 2      5000000
# 3     50000000
# 4       100000
# 5        50000
# 6        50000
# 7      1000000
# 8      1000000
# 9        10000
# 10     1000000
# 11     1000000
# 12    10000000
# 13      100000
# 14      100000
# 15        5000
# 16      500000
# 17       10000
# 18     5000000
# 19    10000000
# Name: Installs, dtype: int64

# %% [markdown]
# ## Exercise 4: Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
google_app["Android Ver"].head(20)
# Out:
# 0     4.0.3 and up
# 1     4.0.3 and up
# 2     4.0.3 and up
# 3       4.2 and up
# 4       4.4 and up
# 5       2.3 and up
# 6     4.0.3 and up
# 7       4.2 and up
# 8       3.0 and up
# 9     4.0.3 and up
# 10      4.1 and up
# 11      4.0 and up
# 12      4.1 and up
# 13      4.4 and up
# 14      2.3 and up
# 15      4.2 and up
# 16      4.1 and up
# 17      2.3 and up
# 18    4.0.3 and up
# 19      4.1 and up
# Name: Android Ver, dtype: object

# %%
google_app["Android Ver"].replace("[a-z]+|[A-z]+", value = "", regex = True, inplace = True) #delete the letters in such a way as to leave only the numerical part
google_app["Current Ver"].replace("[a-z]+|[A-z]+", value = "", regex = True, inplace = True) #delete the letters in such a way as to leave only the numerical part

# %%
google_app["Current Ver"].replace(r"(\.+$)", value = "", regex = True, inplace = True ) 
            #there are values with "." at the end of the numbers so let's remove them

# %%
google_app["Android Ver"] #check it
google_app["Current Ver"] #check it
# Out:
# 0             1.0.0
# 1             2.0.0
# 2             1.2.4
# 3               NaN
# 4               1.1
# 5               1.0
# 6               1.1
# 7          6.1.61.1
# 8             2.9.2
# 9               2.8
# 10            1.0.4
# 11           1.0.15
# 12              3.8
# 13            1.0.4
# 14            1.2.3
# 15              NaN
# 16              3.1
# 17              1.0
# 18            2.2.5
# 19            5.5.4
# 20              4.0
# 21              1.1
# 22          2.2.6.2
# 23            1.0.0
# 24            1.1.3
# 25              1.5
# 26            1.0.8
# 27             1.03
# 28              6.0
# 29              1.0
#             ...
# 10811         1.3.6
# 10812        2.0.20
# 10813        2.1.10
# 10814         1.3.1
# 10815       7.0.4.6
# 10816         2.1.8
# 10817    1.0.612928
# 10818           2.3
# 10819         0.3.4
# 10820         3.8.0
# 10821           1.0
# 10822             1
# 10823           1.0
# 10824         2.2.2
# 10825           1.0
# 10826           NaN
# 10827        2.0.20
# 10828         2.0.1
# 10829          2.96
# 10830           1.5
# 10831     2.0.148.0
# 10832           6.0
# 10833           0.8
# 10834         1.0.0
# 10835         1.1.5
# 10836          1.48
# 10837           1.0
# 10838           1.0
# 10839           NaN
# 10840           NaN
# Name: Current Ver, Length: 10838, dtype: object

# %%
google_app.loc[56] #Let's see a random row
# Out:
# App                Gas Prices (Germany only)
# Category                   AUTO_AND_VEHICLES
# Rating                                   4.4
# Reviews                                  805
# Size (Megabyte)                          5.6
# Installs                               50000
# Type                                    Free
# Price                                      0
# Content Rating                      Everyone
# Genres                       Auto & Vehicles
# Last Updated                   July 29, 2018
# Current Ver                            2.5.1
# Android Ver                            4.4
# Name: 56, dtype: object

# %% [markdown]
# ## Exercise 5: Remove the duplicates
# NB: I suppose that apps with the same name that have fewer reviews are less updated, so: Delete app with less reviews'number

# %%
google_app.drop_duplicates(inplace = True) # first of all, I remove the actual duplicates (for example the app with the same number of rewies and other same details..)

# %%
google_app[google_app["App"] == "Coloring book moana"] #check the indexes of this App
# Out:
#                       App        Category  Rating Reviews  Size (Megabyte)  \
# 1     Coloring book moana  ART_AND_DESIGN     3.9     967             14.0
# 2033  Coloring book moana          FAMILY     3.9     974             14.0
#
#       Installs  Type Price Content Rating                     Genres  \
# 1       500000  Free     0       Everyone  Art & Design;Pretend Play
# 2033    500000  Free     0       Everyone  Art & Design;Pretend Play
#
#           Last Updated Current Ver Android Ver
# 1     January 15, 2018       2.0.0     4.0.3
# 2033  January 15, 2018       2.0.0     4.0.3

# %%
google_app["Reviews"] = pd.to_numeric(google_app["Reviews"]) #they are in a string 
google_app = google_app.loc[google_app.groupby('App', as_index = False, sort = False)['Reviews']\
                   .idxmax()] #group the Apps with the most updated reviews and save the original index for subsequent operations
google_app[google_app["App"] == "Coloring book moana"] #check it after the groupby. It works because it's kept the right index
# Out:
#                       App Category  Rating  Reviews  Size (Megabyte)  \
# 2033  Coloring book moana   FAMILY     3.9      974             14.0
#
#       Installs  Type Price Content Rating                     Genres  \
# 2033    500000  Free     0       Everyone  Art & Design;Pretend Play
#
#           Last Updated Current Ver Android Ver
# 2033  January 15, 2018       2.0.0     4.0.3

# %% [markdown]
# NB: To get a dataframe with index in order just send these two script:

# %%
#google_app = google_app.reset_index() #I create an index in parallel with the original one that is ordered

# %%
#google_app.drop(columns = "index") #now the index is back in order

# %%
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2033                                 Coloring book moana               FAMILY
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 2111                              Mcqueen Coloring pages               FAMILY
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size (Megabyte)  Installs  Type Price Content Rating  \
# 0         4.1      159           19.000     10000  Free     0       Everyone
# 2033      3.9      974           14.000    500000  Free     0       Everyone
# 2         4.7    87510            8.700   5000000  Free     0       Everyone
# 3         4.5   215644           25.000  50000000  Free     0           Teen
# 4         4.3      967            2.800    100000  Free     0       Everyone
# 5         4.4      167            5.600     50000  Free     0       Everyone
# 6         3.8      178           19.000     50000  Free     0       Everyone
# 7         4.1    36815           29.000   1000000  Free     0       Everyone
# 8         4.4    13791           33.000   1000000  Free     0       Everyone
# 9         4.7      121            3.100     10000  Free     0       Everyone
# 10        4.4    13880           28.000   1000000  Free     0       Everyone
# 11        4.4     8788           12.000   1000000  Free     0       Everyone
# 12        4.2    44829           20.000  10000000  Free     0           Teen
# 13        4.6     4326           21.000    100000  Free     0       Everyone
# 14        4.4     1518           37.000    100000  Free     0       Everyone
# 15        3.2       55            2.700      5000  Free     0       Everyone
# 16        4.7     3632            5.500    500000  Free     0       Everyone
# 17        4.5       27           17.000     10000  Free     0       Everyone
# 18        4.3   194216           39.000   5000000  Free     0       Everyone
# 19        4.6   224399           31.000  10000000  Free     0       Everyone
# 20        4.0      450           14.000    100000  Free     0       Everyone
# 21        4.1      654           12.000    100000  Free     0       Everyone
# 22        4.7     7699            4.200    500000  Free     0   Everyone 10+
# 2111      NaN       65            7.000    100000  Free     0       Everyone
# 24        4.7      118           23.000     50000  Free     0       Everyone
# 25        4.8      192            6.000     10000  Free     0       Everyone
# 26        4.7    20260           25.000    500000  Free     0       Everyone
# 27        4.1      203            6.100    100000  Free     0       Everyone
# 28        3.9      136            4.600     10000  Free     0       Everyone
# 29        4.1      223            4.200    100000  Free     0       Everyone
# ...       ...      ...              ...       ...   ...   ...            ...
# 10811     NaN        4            3.900       100  Free     0       Everyone
# 10812     4.1       80           13.000      1000  Free     0       Everyone
# 10813     NaN       20            2.700     10000  Free     0       Everyone
# 10814     4.0      785           31.000     50000  Free     0           Teen
# 10815     4.2     5775            4.900    500000  Free     0       Everyone
# 10816     NaN        2            6.800       100  Free     0       Everyone
# 10817     4.0      885            8.000    100000  Free     0       Everyone
# 10818     NaN       96            1.500     10000  Free     0       Everyone
# 10819     3.3       52            3.600      5000  Free     0           Teen
# 10820     5.0       22            8.600      1000  Free     0           Teen
# 10821     NaN        6            2.500        50  Free     0       Everyone
# 10822     NaN        0            3.100        10  Free     0       Everyone
# 10823     NaN        1            2.900       100  Free     0       Everyone
# 10824     NaN       67           82.000     10000  Free     0       Everyone
# 10825     NaN        7            7.700       100  Free     0           Teen
# 10826     4.0    88486              NaN   5000000  Free     0     Mature 17+
# 10827     4.2      117           13.000      5000  Free     0       Everyone
# 10828     3.4      291           13.000     10000  Free     0       Everyone
# 10829     4.6      603            7.400     10000  Free     0       Everyone
# 10830     3.8      881            2.300    100000  Free     0       Everyone
# 10831     NaN       38            9.800      5000  Free     0       Everyone
# 10832     3.8     1195            0.582    100000  Free     0       Everyone
# 10833     4.8       44            0.619      1000  Free     0       Everyone
# 10834     4.0        7            2.600       500  Free     0       Everyone
# 10835     NaN        0            9.600        10  Free     0       Everyone
# 10836     4.5       38           53.000      5000  Free     0       Everyone
# 10837     5.0        4            3.600       100  Free     0       Everyone
# 10838     NaN        3            9.500      1000  Free     0       Everyone
# 10839     4.5      114              NaN      1000  Free     0     Mature 17+
# 10840     4.5   398307           19.000  10000000  Free     0       Everyone
#
#                                 Genres        Last Updated Current Ver  \
# 0                         Art & Design     January 7, 2018       1.0.0
# 2033         Art & Design;Pretend Play    January 15, 2018       2.0.0
# 2                         Art & Design      August 1, 2018       1.2.4
# 3                         Art & Design        June 8, 2018         NaN
# 4              Art & Design;Creativity       June 20, 2018         1.1
# 5                         Art & Design      March 26, 2017         1.0
# 6                         Art & Design      April 26, 2018         1.1
# 7                         Art & Design       June 14, 2018    6.1.61.1
# 8                         Art & Design  September 20, 2017       2.9.2
# 9              Art & Design;Creativity        July 3, 2018         2.8
# 10                        Art & Design    October 27, 2017       1.0.4
# 11                        Art & Design       July 31, 2018      1.0.15
# 12                        Art & Design       April 2, 2018         3.8
# 13                        Art & Design       June 26, 2018       1.0.4
# 14                        Art & Design      August 3, 2018       1.2.3
# 15                        Art & Design        June 6, 2018         NaN
# 16                        Art & Design       July 31, 2018         3.1
# 17                        Art & Design    November 7, 2017         1.0
# 18                        Art & Design      August 3, 2018       2.2.5
# 19                        Art & Design       July 30, 2018       5.5.4
# 20                        Art & Design      April 20, 2018         4.0
# 21                        Art & Design      March 20, 2018         1.1
# 22                        Art & Design       July 12, 2018     2.2.6.2
# 2111   Art & Design;Action & Adventure       March 7, 2018       1.0.0
# 24                        Art & Design        July 7, 2018       1.1.3
# 25                        Art & Design      April 25, 2018         1.5
# 26             Art & Design;Creativity    October 11, 2017       1.0.8
# 27                        Art & Design      March 21, 2018        1.03
# 28                        Art & Design       July 12, 2018         6.0
# 29                        Art & Design     August 22, 2017         1.0
# ...                                ...                 ...         ...
# 10811                  Auto & Vehicles       July 24, 2018       1.3.6
# 10812                        Education       June 13, 2018      2.0.20
# 10813                         Business       July 17, 2018      2.1.10
# 10814                    Entertainment        June 3, 2015       1.3.1
# 10815                Books & Reference       July 19, 2018     7.0.4.6
# 10816                         Business      August 6, 2018       2.1.8
# 10817                            Tools    October 30, 2015  1.0.612928
# 10818                          Finance        May 19, 2016         2.3
# 10819                Books & Reference      August 5, 2017       0.3.4
# 10820                        Education       June 27, 2018       3.8.0
# 10821                    Entertainment        May 29, 2018         1.0
# 10822                     Productivity    December 1, 2017           1
# 10823          Video Players & Editors      April 22, 2018         1.0
# 10824                          Medical       July 31, 2018       2.2.2
# 10825                           Social    February 2, 2018         1.0
# 10826                           Social      March 23, 2018         NaN
# 10827                        Education       June 13, 2018      2.0.20
# 10828                           Comics        May 15, 2017       2.0.1
# 10829                Books & Reference       June 19, 2016        2.96
# 10830                 News & Magazines    January 20, 2014         1.5
# 10831                Maps & Navigation       June 13, 2018   2.0.148.0
# 10832                          Weather   February 16, 2014         6.0
# 10833                Books & Reference      March 23, 2014         0.8
# 10834                        Education       June 18, 2017       1.0.0
# 10835                         Business  September 29, 2016       1.1.5
# 10836                        Education       July 25, 2017        1.48
# 10837                        Education        July 6, 2018         1.0
# 10838                          Medical    January 20, 2017         1.0
# 10839                Books & Reference    January 19, 2015         NaN
# 10840                        Lifestyle       July 25, 2018         NaN
#
#       Android Ver
# 0         4.0.3
# 2033      4.0.3
# 2         4.0.3
# 3           4.2
# 4           4.4
# 5           2.3
# 6         4.0.3
# 7           4.2
# 8           3.0
# 9         4.0.3
# 10          4.1
# 11          4.0
# 12          4.1
# 13          4.4
# 14          2.3
# 15          4.2
# 16          4.1
# 17          2.3
# 18        4.0.3
# 19          4.1
# 20          4.1
# 21        4.0.3
# 22        4.0.3
# 2111        4.1
# 24          4.1
# 25          3.0
# 26        4.0.3
# 27        4.0.3
# 28          2.3
# 29          2.3
# ...           ...
# 10811       4.4
# 10812     4.0.3
# 10813       4.1
# 10814       3.0
# 10815       4.2
# 10816       4.1
# 10817       5.0
# 10818       2.2
# 10819       4.1
# 10820       4.1
# 10821     4.0.3
# 10822       4.4
# 10823     4.0.3
# 10824       4.4
# 10825       4.0
# 10826         NaN
# 10827     4.0.3
# 10828       4.0
# 10829       4.1
# 10830       1.6
# 10831       4.0
# 10832       2.1
# 10833       2.2
# 10834       4.1
# 10835       4.0
# 10836       4.1
# 10837       4.1
# 10838       2.2
# 10839         NaN
# 10840         NaN
#
# [9657 rows x 13 columns]

# %% [markdown]
# ## Exercise 6: For each category, compute the number of apps

# %%
google_app.groupby("Category", as_index = False)[["App"]].count()
# Out:
#                Category   App
# 0        ART_AND_DESIGN    61
# 1     AUTO_AND_VEHICLES    85
# 2                BEAUTY    53
# 3   BOOKS_AND_REFERENCE   222
# 4              BUSINESS   420
# 5                COMICS    56
# 6         COMMUNICATION   315
# 7                DATING   170
# 8             EDUCATION   107
# 9         ENTERTAINMENT    87
# 10               EVENTS    64
# 11               FAMILY  1874
# 12              FINANCE   345
# 13       FOOD_AND_DRINK   112
# 14                 GAME   946
# 15   HEALTH_AND_FITNESS   288
# 16       HOUSE_AND_HOME    73
# 17   LIBRARIES_AND_DEMO    84
# 18            LIFESTYLE   369
# 19  MAPS_AND_NAVIGATION   131
# 20              MEDICAL   395
# 21   NEWS_AND_MAGAZINES   254
# 22            PARENTING    60
# 23      PERSONALIZATION   374
# 24          PHOTOGRAPHY   281
# 25         PRODUCTIVITY   374
# 26             SHOPPING   202
# 27               SOCIAL   239
# 28               SPORTS   325
# 29                TOOLS   829
# 30     TRAVEL_AND_LOCAL   219
# 31        VIDEO_PLAYERS   164
# 32              WEATHER    79

# %% [markdown]
# ## Exercise 7: For each category, compute the average rating

# %%
google_app.groupby("Category", as_index = False)["Rating"].mean()
# Out:
#                Category    Rating
# 0        ART_AND_DESIGN  4.359322
# 1     AUTO_AND_VEHICLES  4.190411
# 2                BEAUTY  4.278571
# 3   BOOKS_AND_REFERENCE  4.344970
# 4              BUSINESS  4.098479
# 5                COMICS  4.181481
# 6         COMMUNICATION  4.121484
# 7                DATING  3.980451
# 8             EDUCATION  4.354717
# 9         ENTERTAINMENT  4.129885
# 10               EVENTS  4.435556
# 11               FAMILY  4.183445
# 12              FINANCE  4.115563
# 13       FOOD_AND_DRINK  4.171277
# 14                 GAME  4.244605
# 15   HEALTH_AND_FITNESS  4.243033
# 16       HOUSE_AND_HOME  4.140984
# 17   LIBRARIES_AND_DEMO  4.178125
# 18            LIFESTYLE  4.093355
# 19  MAPS_AND_NAVIGATION  4.036441
# 20              MEDICAL  4.165862
# 21   NEWS_AND_MAGAZINES  4.121569
# 22            PARENTING  4.300000
# 23      PERSONALIZATION  4.331419
# 24          PHOTOGRAPHY  4.155894
# 25         PRODUCTIVITY  4.183389
# 26             SHOPPING  4.230556
# 27               SOCIAL  4.247291
# 28               SPORTS  4.216154
# 29                TOOLS  4.040278
# 30     TRAVEL_AND_LOCAL  4.069519
# 31        VIDEO_PLAYERS  4.044966
# 32              WEATHER  4.243056

# %% [markdown]
# ## Exercise 8: Create two dataframes: one for the genres and one bridging apps and genres. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
app_gen = google_app[["App", "Genres"]] #I create a dataframe with only the two columns that interest me
app_gen.head(20) #display the new dataframe
# Out:
#                                                     App  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 2033                                Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
# 5                            Paper flowers instructions
# 6               Smoke Effect Photo Maker - Smoke Editor
# 7                                      Infinite Painter
# 8                                  Garden Coloring Book
# 9                         Kids Paint Free - Drawing Fun
# 10                              Text on Photo - Fonteee
# 11              Name Art Photo Editor - Focus n Filters
# 12                       Tattoo Name On My Photo Editor
# 13                                Mandala Coloring Book
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# 15                      Learn To Draw Kawaii Characters
# 16         Photo Designer - Write your name with shapes
# 17                             350 Diy Room Decor Ideas
# 18                        FlipaClip - Cartoon animation
# 19                                         ibis Paint X
#
#                          Genres
# 0                  Art & Design
# 2033  Art & Design;Pretend Play
# 2                  Art & Design
# 3                  Art & Design
# 4       Art & Design;Creativity
# 5                  Art & Design
# 6                  Art & Design
# 7                  Art & Design
# 8                  Art & Design
# 9       Art & Design;Creativity
# 10                 Art & Design
# 11                 Art & Design
# 12                 Art & Design
# 13                 Art & Design
# 14                 Art & Design
# 15                 Art & Design
# 16                 Art & Design
# 17                 Art & Design
# 18                 Art & Design
# 19                 Art & Design

# %%
gen = app_gen 
c = gen["Genres"].str.split(";", expand = True) #splits the genres after the ";" to have a series divided into multindexes: 0 and 1

# %%
gen["Genres1"] = c[0] #create the first column for the first genre
gen["Genres2"] = c[1] #create the second column for the second genre
genres = gen[["Genres1", "Genres2"]] #I create the first dataframe composed of the two genres columns 
app = google_app[["App"]]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
genres.head()
# Out:
#            Genres1       Genres2
# 0     Art & Design          None
# 2033  Art & Design  Pretend Play
# 2     Art & Design          None
# 3     Art & Design          None
# 4     Art & Design    Creativity

# %%
app_genres = pd.merge(app, genres, left_index = True, right_index = True)\
            .melt(id_vars = ['App'], value_name = "Genres").drop(columns = "variable") #Merge (inner join default) apps with genres and then melt them by app column
                                                                #melt is useful for having only one column for genres 
                                                                #delete the variable column that is not useful for our purpose

# %%
app_genres = app_genres.dropna() #delete the remaining NAN

# %%
app_genres.head() #the second dataframe required by the exercise
# Out:
#                                                  App        Genres
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 3                              Sketch - Draw & Paint  Art & Design
# 4              Pixel Draw - Number Art Coloring Book  Art & Design

# %%
app_genres.info() #check composition of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10049 entries, 0 to 19006
# Data columns (total 2 columns):
# App       10049 non-null object
# Genres    10049 non-null object
# dtypes: object(2)
# memory usage: 235.5+ KB

# %%
app_genres[app_genres["App"] == "Coloring book moana"] #check if everything works correctly
# Out:
#                       App        Genres
# 1     Coloring book moana  Art & Design
# 9658  Coloring book moana  Pretend Play

# %% [markdown]
# ## Exercise 9: For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
new_google_app = pd.concat([google_app, pd.get_dummies(genres["Genres1"], dtype = "bool")], axis= 1).drop(columns = "Genres") #concatenate genres1 binaryized
new_google_app = pd.concat([new_google_app, pd.get_dummies(genres["Genres2"], dtype = "bool")], axis= 1) #axis one for the columns 
                            #concatenate genres2 binaryized
                            #all this done to have binarization with related values

# %%
new_google_app.head() #check the new dataframe and whether they are related 
new_google_app[["App", "Art & Design", "Pretend Play"]].loc[2033]
# Out:
# App             Coloring book moana
# Art & Design                   True
# Pretend Play                   True
# Name: 2033, dtype: object

# %% [markdown]
# ## Exercise 10: For each genre, compute the average rating. What is the genre with highest average?

# %%
google_app_3 = app_genres.merge(google_app, on = "App")
google_app_3.drop(columns = "Genres_y", inplace = True) #dropping the column that I don't need 
google_app_3.head()
# Out:
#                                                  App      Genres_x  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2                                Coloring book moana  Pretend Play
# 3  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 4                              Sketch - Draw & Paint  Art & Design
#
#          Category  Rating  Reviews  Size (Megabyte)  Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159             19.0     10000  Free     0
# 1          FAMILY     3.9      974             14.0    500000  Free     0
# 2          FAMILY     3.9      974             14.0    500000  Free     0
# 3  ART_AND_DESIGN     4.7    87510              8.7   5000000  Free     0
# 4  ART_AND_DESIGN     4.5   215644             25.0  50000000  Free     0
#
#   Content Rating      Last Updated Current Ver Android Ver
# 0       Everyone   January 7, 2018       1.0.0     4.0.3
# 1       Everyone  January 15, 2018       2.0.0     4.0.3
# 2       Everyone  January 15, 2018       2.0.0     4.0.3
# 3       Everyone    August 1, 2018       1.2.4     4.0.3
# 4           Teen      June 8, 2018         NaN       4.2

# %%
google_app_3.groupby('Genres_x', as_index = False, sort = False)[['Rating']].mean()
# Out:
#                    Genres_x    Rating
# 0              Art & Design  4.350000
# 1              Pretend Play  4.238235
# 2                Creativity  4.306250
# 3        Action & Adventure  4.288542
# 4           Auto & Vehicles  4.190411
# 5                    Beauty  4.278571
# 6         Books & Reference  4.343275
# 7                  Business  4.098479
# 8                    Comics  4.181481
# 9             Communication  4.121790
# 10                   Dating  3.980451
# 11                    Tools  4.040278
# 12                Education  4.290290
# 13            Music & Video  4.229032
# 14              Brain Games  4.358065
# 15            Entertainment  4.093028
# 16                   Events  4.435556
# 17                  Finance  4.115563
# 18             Food & Drink  4.171277
# 19         Health & Fitness  4.243496
# 20             House & Home  4.140984
# 21         Libraries & Demo  4.178125
# 22                Lifestyle  4.094040
# 23                Adventure  4.191026
# 24                   Arcade  4.277838
# 25                   Casual  4.141014
# 26                     Card  4.082609
# 27                   Action  4.247697
# 28                 Strategy  4.227368
# 29                   Puzzle  4.370732
# 30                   Sports  4.225185
# 31                    Music  4.219048
# 32                     Word  4.318182
# 33                   Racing  4.174757
# 34               Simulation  4.154500
# 35                    Board  4.291228
# 36                   Trivia  4.039286
# 37             Role Playing  4.272072
# 38              Educational  4.100000
# 39            Music & Audio  4.300000
# 40  Video Players & Editors  4.044667
# 41                  Medical  4.165862
# 42                   Social  4.247291
# 43                 Shopping  4.230556
# 44              Photography  4.155894
# 45           Travel & Local  4.069519
# 46          Personalization  4.331419
# 47             Productivity  4.183389
# 48                Parenting  4.300000
# 49                  Weather  4.243056
# 50         News & Magazines  4.121569
# 51        Maps & Navigation  4.036441
# 52                   Casino  4.286486

# %%
print("The average of the highest rating corresponds to the genre: "+google_app_3.groupby('Genres_x')['Rating'].mean().argmax())
# Out:
# The average of the highest rating corresponds to the genre: Events
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Exercise 11: For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
google_app["Price"].value_counts() #let's see the composition of values in "$"
google_app["Price"].replace(r"(\$)", value = "", regex = True, inplace = True) #delete "$"
google_app["Price"] = pd.to_numeric(google_app["Price"]) #from string to number

# %%
google_app["app_income"] = google_app["Price"] * google_app["Installs"] #create new column for the approximate income

# %%
google_app.loc[60]
# Out:
# App                     CityBus Lviv
# Category           AUTO_AND_VEHICLES
# Rating                           4.6
# Reviews                          534
# Size (Megabyte)                  5.7
# Installs                       10000
# Type                            Free
# Price                              0
# Content Rating              Everyone
# Genres               Auto & Vehicles
# Last Updated            July 8, 2018
# Current Ver                    1.9.1
# Android Ver                  4.0.3
# app_income                         0
# Name: 60, dtype: object

# %% [markdown]
# ## Exercise 12: or each app, compute its minimum and maximum Sentiment_polarity

# %%
user_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
sentimentmin = user_reviews.groupby("App", sort = False, as_index = False)["Sentiment_Polarity"].min()

# %%
sentimentmin.head()
# Out:
#                                 App  Sentiment_Polarity
# 0             10 Best Foods for You             -0.8000
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室             -0.1125
# 2                              11st             -1.0000
# 3        1800 Contacts - Lens Store             -0.3000
# 4   1LINE – One Line with One Touch             -0.8250

# %%
sentimentmax = user_reviews.groupby("App", sort = False, as_index = False)["Sentiment_Polarity"].max()

# %%
sentimentmax.head()
# Out:
#                                 App  Sentiment_Polarity
# 0             10 Best Foods for You            1.000000
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室            0.910000
# 2                              11st            1.000000
# 3        1800 Contacts - Lens Store            0.838542
# 4   1LINE – One Line with One Touch            1.000000
